# %%
import pyspark as ps
from pyspark.sql import SparkSession
from pyspark.ml.feature import VectorAssembler
from pyspark.ml import Pipeline
from pyspark.ml.evaluation import BinaryClassificationEvaluator
from pyspark.ml.tuning import ParamGridBuilder

from pyspark.ml.classification import RandomForestClassifier
from xgboost.spark import SparkXGBClassifier

import os

# %%
# Copied from https://github.com/interviewstreet/spark-stratifier/blob/master/spark_stratifier/stratifier.py
import itertools
import numpy as np

from pyspark import since, keyword_only
from pyspark.ml import Estimator, Model
from pyspark.ml.common import _py2java
from pyspark.ml.param import Params, Param, TypeConverters
from pyspark.ml.param.shared import HasSeed
from pyspark.ml.tuning import CrossValidator, CrossValidatorModel
from pyspark.ml.util import *
from pyspark.ml.wrapper import JavaParams
from pyspark.sql.functions import rand
from functools import reduce

class StratifiedCrossValidator(CrossValidator):
  def stratify_data(self, dataset):
    """
    Returns an array of dataframes with the same ratio of passes and failures.

    Currently only supports binary classification problems.
    """

    epm = self.getOrDefault(self.estimatorParamMaps)
    numModels = len(epm)
    nFolds = self.getOrDefault(self.numFolds)
    split_ratio = 1.0 / nFolds

    passes = dataset[dataset['label'] == 1]
    fails = dataset[dataset['label'] == 0]

    pass_splits = passes.randomSplit([split_ratio for i in range(nFolds)])
    fail_splits = fails.randomSplit([split_ratio for i in range(nFolds)])

    stratified_data = [pass_splits[i].unionAll(fail_splits[i]) for i in range(nFolds)]

    return stratified_data

  def _fit(self, dataset):
    est = self.getOrDefault(self.estimator)
    epm = self.getOrDefault(self.estimatorParamMaps)
    numModels = len(epm)
    eva = self.getOrDefault(self.evaluator)
    nFolds = self.getOrDefault(self.numFolds)
    seed = self.getOrDefault(self.seed)
    metrics = [0.0] * numModels

    stratified_data = self.stratify_data(dataset)

    for i in range(nFolds):
      train_arr = [x for j,x in enumerate(stratified_data) if j != i]
      train = reduce((lambda x, y: x.unionAll(y)), train_arr)
      validation = stratified_data[i]

      models = est.fit(train, epm)

      for j in range(numModels):
        model = models[j]
        metric = eva.evaluate(model.transform(validation, epm[j]))
        metrics[j] += metric/nFolds

    if eva.isLargerBetter():
      bestIndex = np.argmax(metrics)
    else:
      bestIndex = np.argmin(metrics)

    bestModel = est.fit(dataset, epm[bestIndex])
    return self._copyValues(CrossValidatorModel(bestModel, metrics))

# %%
spark = SparkSession.builder.appName("Insurance Cross Selling").getOrCreate()
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://vboxuser.home:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Insurance Cross Selling</code></dd>
#             </dl>
#         </div>
#
#             </div>
# [Stage 1:>                                                         (0 + 6) / 60]

# %%
df = spark.read.format("csv").options(
        header=True,
        inferSchema=True
    ).load("hdfs://localhost:9000/s4e7/normalized.csv")
df.printSchema()
# Out:
# [Stage 3:========================================================>(59 + 1) / 60]
# root
#  |-- id: integer (nullable = true)
#  |-- Gender: integer (nullable = true)
#  |-- Age: integer (nullable = true)
#  |-- Driving_License: integer (nullable = true)
#  |-- Region_Code_0: integer (nullable = true)
#  |-- Region_Code_1: integer (nullable = true)
#  |-- Region_Code_10: integer (nullable = true)
#  |-- Region_Code_11: integer (nullable = true)
#  |-- Region_Code_12: integer (nullable = true)
#  |-- Region_Code_13: integer (nullable = true)
#  |-- Region_Code_14: integer (nullable = true)
#  |-- Region_Code_15: integer (nullable = true)
#  |-- Region_Code_16: integer (nullable = true)
#  |-- Region_Code_17: integer (nullable = true)
#  |-- Region_Code_18: integer (nullable = true)
#  |-- Region_Code_19: integer (nullable = true)
#  |-- Region_Code_2: integer (nullable = true)
#  |-- Region_Code_20: integer (nullable = true)
#  |-- Region_Code_21: integer (nullable = true)
#  |-- Region_Code_22: integer (nullable = true)
#  |-- Region_Code_23: integer (nullable = true)
#  |-- Region_Code_24: integer (nullable = true)
#  |-- Region_Code_25: integer (nullable = true)
#  |-- Region_Code_26: integer (nullable = true)
#  |-- Region_Code_27: integer (nullable = true)
#  |-- Region_Code_28: integer (nullable = true)
#  |-- Region_Code_29: integer (nullable = true)
#  |-- Region_Code_3: integer (nullable = true)
#  |-- Region_Code_30: integer (nullable = true)
#  |-- Region_Code_31: integer (nullable = true)
#  |-- Region_Code_32: integer (nullable = true)
#  |-- Region_Code_33: integer (nullable = true)
#  |-- Region_Code_34: integer (nullable = true)
#  |-- Region_Code_35: integer (nullable = true)
#  |-- Region_Code_36: integer (nullable = true)
#  |-- Region_Code_37: integer (nullable = true)
#  |-- Region_Code_38: integer (nullable = true)
#  |-- Region_Code_39: integer (nullable = true)
#  |-- Region_Code_4: integer (nullable = true)
#  |-- Region_Code_40: integer (nullable = true)
#  |-- Region_Code_41: integer (nullable = true)
#  |-- Region_Code_42: integer (nullable = true)
#  |-- Region_Code_43: integer (nullable = true)
#  |-- Region_Code_44: integer (nullable = true)
#  |-- Region_Code_45: integer (nullable = true)
#  |-- Region_Code_46: integer (nullable = true)
#  |-- Region_Code_47: integer (nullable = true)
#  |-- Region_Code_48: integer (nullable = true)
#  |-- Region_Code_49: integer (nullable = true)
#  |-- Region_Code_5: integer (nullable = true)
#  |-- Region_Code_50: integer (nullable = true)
#  |-- Region_Code_51: integer (nullable = true)
#  |-- Region_Code_52: integer (nullable = true)
#  |-- Region_Code_6: integer (nullable = true)
#  |-- Region_Code_7: integer (nullable = true)
#  |-- Region_Code_8: integer (nullable = true)
#  |-- Region_Code_9: integer (nullable = true)
#  |-- Previously_Insured: integer (nullable = true)
#  |-- Vehicle_Age_1-2 Year: integer (nullable = true)
#  |-- Vehicle_Age_< 1 Year: integer (nullable = true)
#  |-- Vehicle_Age_> 2 Years: integer (nullable = true)
#  |-- Vehicle_Damage: integer (nullable = true)
#  |-- Annual_Premium: double (nullable = true)
#  |-- Policy_Sales_Channel_1: integer (nullable = true)
#  |-- Policy_Sales_Channel_10: integer (nullable = true)
#  |-- Policy_Sales_Channel_100: integer (nullable = true)
#  |-- Policy_Sales_Channel_101: integer (nullable = true)
#  |-- Policy_Sales_Channel_102: integer (nullable = true)
#  |-- Policy_Sales_Channel_103: integer (nullable = true)
#  |-- Policy_Sales_Channel_104: integer (nullable = true)
#  |-- Policy_Sales_Channel_105: integer (nullable = true)
#  |-- Policy_Sales_Channel_106: integer (nullable = true)
#  |-- Policy_Sales_Channel_107: integer (nullable = true)
#  |-- Policy_Sales_Channel_108: integer (nullable = true)
#  |-- Policy_Sales_Channel_109: integer (nullable = true)
#  |-- Policy_Sales_Channel_11: integer (nullable = true)
#  |-- Policy_Sales_Channel_110: integer (nullable = true)
#  |-- Policy_Sales_Channel_111: integer (nullable = true)
#  |-- Policy_Sales_Channel_113: integer (nullable = true)
#  |-- Policy_Sales_Channel_114: integer (nullable = true)
#  |-- Policy_Sales_Channel_115: integer (nullable = true)
#  |-- Policy_Sales_Channel_116: integer (nullable = true)
#  |-- Policy_Sales_Channel_117: integer (nullable = true)
#  |-- Policy_Sales_Channel_118: integer (nullable = true)
#  |-- Policy_Sales_Channel_119: integer (nullable = true)
#  |-- Policy_Sales_Channel_12: integer (nullable = true)
#  |-- Policy_Sales_Channel_120: integer (nullable = true)
#  |-- Policy_Sales_Channel_121: integer (nullable = true)
#  |-- Policy_Sales_Channel_122: integer (nullable = true)
#  |-- Policy_Sales_Channel_123: integer (nullable = true)
#  |-- Policy_Sales_Channel_124: integer (nullable = true)
#  |-- Policy_Sales_Channel_125: integer (nullable = true)
#  |-- Policy_Sales_Channel_126: integer (nullable = true)
#  |-- Policy_Sales_Channel_127: integer (nullable = true)
#  |-- Policy_Sales_Channel_128: integer (nullable = true)
#  |-- Policy_Sales_Channel_129: integer (nullable = true)
#  |-- Policy_Sales_Channel_13: integer (nullable = true)
#  |-- Policy_Sales_Channel_130: integer (nullable = true)
#  |-- Policy_Sales_Channel_131: integer (nullable = true)
#  |-- Policy_Sales_Channel_132: integer (nullable = true)
#  |-- Policy_Sales_Channel_133: integer (nullable = true)
#  |-- Policy_Sales_Channel_134: integer (nullable = true)
#  |-- Policy_Sales_Channel_135: integer (nullable = true)
#  |-- Policy_Sales_Channel_136: integer (nullable = true)
#  |-- Policy_Sales_Channel_137: integer (nullable = true)
#  |-- Policy_Sales_Channel_138: integer (nullable = true)
#  |-- Policy_Sales_Channel_139: integer (nullable = true)
#  |-- Policy_Sales_Channel_14: integer (nullable = true)
#  |-- Policy_Sales_Channel_140: integer (nullable = true)
#  |-- Policy_Sales_Channel_145: integer (nullable = true)
#  |-- Policy_Sales_Channel_146: integer (nullable = true)
#  |-- Policy_Sales_Channel_147: integer (nullable = true)
#  |-- Policy_Sales_Channel_148: integer (nullable = true)
#  |-- Policy_Sales_Channel_15: integer (nullable = true)
#  |-- Policy_Sales_Channel_150: integer (nullable = true)
#  |-- Policy_Sales_Channel_151: integer (nullable = true)
#  |-- Policy_Sales_Channel_152: integer (nullable = true)
#  |-- Policy_Sales_Channel_153: integer (nullable = true)
#  |-- Policy_Sales_Channel_154: integer (nullable = true)
#  |-- Policy_Sales_Channel_155: integer (nullable = true)
#  |-- Policy_Sales_Channel_156: integer (nullable = true)
#  |-- Policy_Sales_Channel_157: integer (nullable = true)
#  |-- Policy_Sales_Channel_158: integer (nullable = true)
#  |-- Policy_Sales_Channel_159: integer (nullable = true)
#  |-- Policy_Sales_Channel_16: integer (nullable = true)
#  |-- Policy_Sales_Channel_160: integer (nullable = true)
#  |-- Policy_Sales_Channel_163: integer (nullable = true)
#  |-- Policy_Sales_Channel_17: integer (nullable = true)
#  |-- Policy_Sales_Channel_18: integer (nullable = true)
#  |-- Policy_Sales_Channel_19: integer (nullable = true)
#  |-- Policy_Sales_Channel_2: integer (nullable = true)
#  |-- Policy_Sales_Channel_20: integer (nullable = true)
#  |-- Policy_Sales_Channel_21: integer (nullable = true)
#  |-- Policy_Sales_Channel_22: integer (nullable = true)
#  |-- Policy_Sales_Channel_23: integer (nullable = true)
#  |-- Policy_Sales_Channel_24: integer (nullable = true)
#  |-- Policy_Sales_Channel_25: integer (nullable = true)
#  |-- Policy_Sales_Channel_26: integer (nullable = true)
#  |-- Policy_Sales_Channel_27: integer (nullable = true)
#  |-- Policy_Sales_Channel_28: integer (nullable = true)
#  |-- Policy_Sales_Channel_29: integer (nullable = true)
#  |-- Policy_Sales_Channel_3: integer (nullable = true)
#  |-- Policy_Sales_Channel_30: integer (nullable = true)
#  |-- Policy_Sales_Channel_31: integer (nullable = true)
#  |-- Policy_Sales_Channel_32: integer (nullable = true)
#  |-- Policy_Sales_Channel_33: integer (nullable = true)
#  |-- Policy_Sales_Channel_34: integer (nullable = true)
#  |-- Policy_Sales_Channel_35: integer (nullable = true)
#  |-- Policy_Sales_Channel_36: integer (nullable = true)
#  |-- Policy_Sales_Channel_37: integer (nullable = true)
#  |-- Policy_Sales_Channel_38: integer (nullable = true)
#  |-- Policy_Sales_Channel_39: integer (nullable = true)
#  |-- Policy_Sales_Channel_4: integer (nullable = true)
#  |-- Policy_Sales_Channel_40: integer (nullable = true)
#  |-- Policy_Sales_Channel_42: integer (nullable = true)
#  |-- Policy_Sales_Channel_43: integer (nullable = true)
#  |-- Policy_Sales_Channel_44: integer (nullable = true)
#  |-- Policy_Sales_Channel_45: integer (nullable = true)
#  |-- Policy_Sales_Channel_46: integer (nullable = true)
#  |-- Policy_Sales_Channel_47: integer (nullable = true)
#  |-- Policy_Sales_Channel_48: integer (nullable = true)
#  |-- Policy_Sales_Channel_49: integer (nullable = true)
#  |-- Policy_Sales_Channel_5: integer (nullable = true)
#  |-- Policy_Sales_Channel_50: integer (nullable = true)
#  |-- Policy_Sales_Channel_51: integer (nullable = true)
#  |-- Policy_Sales_Channel_52: integer (nullable = true)
#  |-- Policy_Sales_Channel_53: integer (nullable = true)
#  |-- Policy_Sales_Channel_54: integer (nullable = true)
#  |-- Policy_Sales_Channel_55: integer (nullable = true)
#  |-- Policy_Sales_Channel_56: integer (nullable = true)
#  |-- Policy_Sales_Channel_57: integer (nullable = true)
#  |-- Policy_Sales_Channel_58: integer (nullable = true)
#  |-- Policy_Sales_Channel_59: integer (nullable = true)
#  |-- Policy_Sales_Channel_6: integer (nullable = true)
#  |-- Policy_Sales_Channel_60: integer (nullable = true)
#  |-- Policy_Sales_Channel_61: integer (nullable = true)
#  |-- Policy_Sales_Channel_62: integer (nullable = true)
#  |-- Policy_Sales_Channel_63: integer (nullable = true)
#  |-- Policy_Sales_Channel_64: integer (nullable = true)
#  |-- Policy_Sales_Channel_65: integer (nullable = true)
#  |-- Policy_Sales_Channel_66: integer (nullable = true)
#  |-- Policy_Sales_Channel_67: integer (nullable = true)
#  |-- Policy_Sales_Channel_68: integer (nullable = true)
#  |-- Policy_Sales_Channel_69: integer (nullable = true)
#  |-- Policy_Sales_Channel_7: integer (nullable = true)
#  |-- Policy_Sales_Channel_70: integer (nullable = true)
#  |-- Policy_Sales_Channel_71: integer (nullable = true)
#  |-- Policy_Sales_Channel_73: integer (nullable = true)
#  |-- Policy_Sales_Channel_74: integer (nullable = true)
#  |-- Policy_Sales_Channel_75: integer (nullable = true)
#  |-- Policy_Sales_Channel_76: integer (nullable = true)
#  |-- Policy_Sales_Channel_78: integer (nullable = true)
#  |-- Policy_Sales_Channel_79: integer (nullable = true)
#  |-- Policy_Sales_Channel_8: integer (nullable = true)
#  |-- Policy_Sales_Channel_80: integer (nullable = true)
#  |-- Policy_Sales_Channel_81: integer (nullable = true)
#  |-- Policy_Sales_Channel_82: integer (nullable = true)
#  |-- Policy_Sales_Channel_83: integer (nullable = true)
#  |-- Policy_Sales_Channel_86: integer (nullable = true)
#  |-- Policy_Sales_Channel_87: integer (nullable = true)
#  |-- Policy_Sales_Channel_88: integer (nullable = true)
#  |-- Policy_Sales_Channel_89: integer (nullable = true)
#  |-- Policy_Sales_Channel_9: integer (nullable = true)
#  |-- Policy_Sales_Channel_90: integer (nullable = true)
#  |-- Policy_Sales_Channel_91: integer (nullable = true)
#  |-- Policy_Sales_Channel_92: integer (nullable = true)
#  |-- Policy_Sales_Channel_93: integer (nullable = true)
#  |-- Policy_Sales_Channel_94: integer (nullable = true)
#  |-- Policy_Sales_Channel_95: integer (nullable = true)
#  |-- Policy_Sales_Channel_96: integer (nullable = true)
#  |-- Policy_Sales_Channel_97: integer (nullable = true)
#  |-- Policy_Sales_Channel_99: integer (nullable = true)
#  |-- Vintage_10: integer (nullable = true)
#  |-- Vintage_100: integer (nullable = true)
#  |-- Vintage_101: integer (nullable = true)
#  |-- Vintage_102: integer (nullable = true)
#  |-- Vintage_103: integer (nullable = true)
#  |-- Vintage_104: integer (nullable = true)
#  |-- Vintage_105: integer (nullable = true)
#  |-- Vintage_106: integer (nullable = true)
#  |-- Vintage_107: integer (nullable = true)
#  |-- Vintage_108: integer (nullable = true)
#  |-- Vintage_109: integer (nullable = true)
#  |-- Vintage_11: integer (nullable = true)
#  |-- Vintage_110: integer (nullable = true)
#  |-- Vintage_111: integer (nullable = true)
#  |-- Vintage_112: integer (nullable = true)
#  |-- Vintage_113: integer (nullable = true)
#  |-- Vintage_114: integer (nullable = true)
#  |-- Vintage_115: integer (nullable = true)
#  |-- Vintage_116: integer (nullable = true)
#  |-- Vintage_117: integer (nullable = true)
#  |-- Vintage_118: integer (nullable = true)
#  |-- Vintage_119: integer (nullable = true)
#  |-- Vintage_12: integer (nullable = true)
#  |-- Vintage_120: integer (nullable = true)
#  |-- Vintage_121: integer (nullable = true)
#  |-- Vintage_122: integer (nullable = true)
#  |-- Vintage_123: integer (nullable = true)
#  |-- Vintage_124: integer (nullable = true)
#  |-- Vintage_125: integer (nullable = true)
#  |-- Vintage_126: integer (nullable = true)
#  |-- Vintage_127: integer (nullable = true)
#  |-- Vintage_128: integer (nullable = true)
#  |-- Vintage_129: integer (nullable = true)
#  |-- Vintage_13: integer (nullable = true)
#  |-- Vintage_130: integer (nullable = true)
#  |-- Vintage_131: integer (nullable = true)
#  |-- Vintage_132: integer (nullable = true)
#  |-- Vintage_133: integer (nullable = true)
#  |-- Vintage_134: integer (nullable = true)
#  |-- Vintage_135: integer (nullable = true)
#  |-- Vintage_136: integer (nullable = true)
#  |-- Vintage_137: integer (nullable = true)
#  |-- Vintage_138: integer (nullable = true)
#  |-- Vintage_139: integer (nullable = true)
#  |-- Vintage_14: integer (nullable = true)
#  |-- Vintage_140: integer (nullable = true)
#  |-- Vintage_141: integer (nullable = true)
#  |-- Vintage_142: integer (nullable = true)
#  |-- Vintage_143: integer (nullable = true)
#  |-- Vintage_144: integer (nullable = true)
#  |-- Vintage_145: integer (nullable = true)
#  |-- Vintage_146: integer (nullable = true)
#  |-- Vintage_147: integer (nullable = true)
#  |-- Vintage_148: integer (nullable = true)
#  |-- Vintage_149: integer (nullable = true)
#  |-- Vintage_15: integer (nullable = true)
#  |-- Vintage_150: integer (nullable = true)
#  |-- Vintage_151: integer (nullable = true)
#  |-- Vintage_152: integer (nullable = true)
#  |-- Vintage_153: integer (nullable = true)
#  |-- Vintage_154: integer (nullable = true)
#  |-- Vintage_155: integer (nullable = true)
#  |-- Vintage_156: integer (nullable = true)
#  |-- Vintage_157: integer (nullable = true)
#  |-- Vintage_158: integer (nullable = true)
#  |-- Vintage_159: integer (nullable = true)
#  |-- Vintage_16: integer (nullable = true)
#  |-- Vintage_160: integer (nullable = true)
#  |-- Vintage_161: integer (nullable = true)
#  |-- Vintage_162: integer (nullable = true)
#  |-- Vintage_163: integer (nullable = true)
#  |-- Vintage_164: integer (nullable = true)
#  |-- Vintage_165: integer (nullable = true)
#  |-- Vintage_166: integer (nullable = true)
#  |-- Vintage_167: integer (nullable = true)
#  |-- Vintage_168: integer (nullable = true)
#  |-- Vintage_169: integer (nullable = true)
#  |-- Vintage_17: integer (nullable = true)
#  |-- Vintage_170: integer (nullable = true)
#  |-- Vintage_171: integer (nullable = true)
#  |-- Vintage_172: integer (nullable = true)
#  |-- Vintage_173: integer (nullable = true)
#  |-- Vintage_174: integer (nullable = true)
#  |-- Vintage_175: integer (nullable = true)
#  |-- Vintage_176: integer (nullable = true)
#  |-- Vintage_177: integer (nullable = true)
#  |-- Vintage_178: integer (nullable = true)
#  |-- Vintage_179: integer (nullable = true)
#  |-- Vintage_18: integer (nullable = true)
#  |-- Vintage_180: integer (nullable = true)
#  |-- Vintage_181: integer (nullable = true)
#  |-- Vintage_182: integer (nullable = true)
#  |-- Vintage_183: integer (nullable = true)
#  |-- Vintage_184: integer (nullable = true)
#  |-- Vintage_185: integer (nullable = true)
#  |-- Vintage_186: integer (nullable = true)
#  |-- Vintage_187: integer (nullable = true)
#  |-- Vintage_188: integer (nullable = true)
#  |-- Vintage_189: integer (nullable = true)
#  |-- Vintage_19: integer (nullable = true)
#  |-- Vintage_190: integer (nullable = true)
#  |-- Vintage_191: integer (nullable = true)
#  |-- Vintage_192: integer (nullable = true)
#  |-- Vintage_193: integer (nullable = true)
#  |-- Vintage_194: integer (nullable = true)
#  |-- Vintage_195: integer (nullable = true)
#  |-- Vintage_196: integer (nullable = true)
#  |-- Vintage_197: integer (nullable = true)
#  |-- Vintage_198: integer (nullable = true)
#  |-- Vintage_199: integer (nullable = true)
#  |-- Vintage_20: integer (nullable = true)
#  |-- Vintage_200: integer (nullable = true)
#  |-- Vintage_201: integer (nullable = true)
#  |-- Vintage_202: integer (nullable = true)
#  |-- Vintage_203: integer (nullable = true)
#  |-- Vintage_204: integer (nullable = true)
#  |-- Vintage_205: integer (nullable = true)
#  |-- Vintage_206: integer (nullable = true)
#  |-- Vintage_207: integer (nullable = true)
#  |-- Vintage_208: integer (nullable = true)
#  |-- Vintage_209: integer (nullable = true)
#  |-- Vintage_21: integer (nullable = true)
#  |-- Vintage_210: integer (nullable = true)
#  |-- Vintage_211: integer (nullable = true)
#  |-- Vintage_212: integer (nullable = true)
#  |-- Vintage_213: integer (nullable = true)
#  |-- Vintage_214: integer (nullable = true)
#  |-- Vintage_215: integer (nullable = true)
#  |-- Vintage_216: integer (nullable = true)
#  |-- Vintage_217: integer (nullable = true)
#  |-- Vintage_218: integer (nullable = true)
#  |-- Vintage_219: integer (nullable = true)
#  |-- Vintage_22: integer (nullable = true)
#  |-- Vintage_220: integer (nullable = true)
#  |-- Vintage_221: integer (nullable = true)
#  |-- Vintage_222: integer (nullable = true)
#  |-- Vintage_223: integer (nullable = true)
#  |-- Vintage_224: integer (nullable = true)
#  |-- Vintage_225: integer (nullable = true)
#  |-- Vintage_226: integer (nullable = true)
#  |-- Vintage_227: integer (nullable = true)
#  |-- Vintage_228: integer (nullable = true)
#  |-- Vintage_229: integer (nullable = true)
#  |-- Vintage_23: integer (nullable = true)
#  |-- Vintage_230: integer (nullable = true)
#  |-- Vintage_231: integer (nullable = true)
#  |-- Vintage_232: integer (nullable = true)
#  |-- Vintage_233: integer (nullable = true)
#  |-- Vintage_234: integer (nullable = true)
#  |-- Vintage_235: integer (nullable = true)
#  |-- Vintage_236: integer (nullable = true)
#  |-- Vintage_237: integer (nullable = true)
#  |-- Vintage_238: integer (nullable = true)
#  |-- Vintage_239: integer (nullable = true)
#  |-- Vintage_24: integer (nullable = true)
#  |-- Vintage_240: integer (nullable = true)
#  |-- Vintage_241: integer (nullable = true)
#  |-- Vintage_242: integer (nullable = true)
#  |-- Vintage_243: integer (nullable = true)
#  |-- Vintage_244: integer (nullable = true)
#  |-- Vintage_245: integer (nullable = true)
#  |-- Vintage_246: integer (nullable = true)
#  |-- Vintage_247: integer (nullable = true)
#  |-- Vintage_248: integer (nullable = true)
#  |-- Vintage_249: integer (nullable = true)
#  |-- Vintage_25: integer (nullable = true)
#  |-- Vintage_250: integer (nullable = true)
#  |-- Vintage_251: integer (nullable = true)
#  |-- Vintage_252: integer (nullable = true)
#  |-- Vintage_253: integer (nullable = true)
#  |-- Vintage_254: integer (nullable = true)
#  |-- Vintage_255: integer (nullable = true)
#  |-- Vintage_256: integer (nullable = true)
#  |-- Vintage_257: integer (nullable = true)
#  |-- Vintage_258: integer (nullable = true)
#  |-- Vintage_259: integer (nullable = true)
#  |-- Vintage_26: integer (nullable = true)
#  |-- Vintage_260: integer (nullable = true)
#  |-- Vintage_261: integer (nullable = true)
#  |-- Vintage_262: integer (nullable = true)
#  |-- Vintage_263: integer (nullable = true)
#  |-- Vintage_264: integer (nullable = true)
#  |-- Vintage_265: integer (nullable = true)
#  |-- Vintage_266: integer (nullable = true)
#  |-- Vintage_267: integer (nullable = true)
#  |-- Vintage_268: integer (nullable = true)
#  |-- Vintage_269: integer (nullable = true)
#  |-- Vintage_27: integer (nullable = true)
#  |-- Vintage_270: integer (nullable = true)
#  |-- Vintage_271: integer (nullable = true)
#  |-- Vintage_272: integer (nullable = true)
#  |-- Vintage_273: integer (nullable = true)
#  |-- Vintage_274: integer (nullable = true)
#  |-- Vintage_275: integer (nullable = true)
#  |-- Vintage_276: integer (nullable = true)
#  |-- Vintage_277: integer (nullable = true)
#  |-- Vintage_278: integer (nullable = true)
#  |-- Vintage_279: integer (nullable = true)
#  |-- Vintage_28: integer (nullable = true)
#  |-- Vintage_280: integer (nullable = true)
#  |-- Vintage_281: integer (nullable = true)
#  |-- Vintage_282: integer (nullable = true)
#  |-- Vintage_283: integer (nullable = true)
#  |-- Vintage_284: integer (nullable = true)
#  |-- Vintage_285: integer (nullable = true)
#  |-- Vintage_286: integer (nullable = true)
#  |-- Vintage_287: integer (nullable = true)
#  |-- Vintage_288: integer (nullable = true)
#  |-- Vintage_289: integer (nullable = true)
#  |-- Vintage_29: integer (nullable = true)
#  |-- Vintage_290: integer (nullable = true)
#  |-- Vintage_291: integer (nullable = true)
#  |-- Vintage_292: integer (nullable = true)
#  |-- Vintage_293: integer (nullable = true)
#  |-- Vintage_294: integer (nullable = true)
#  |-- Vintage_295: integer (nullable = true)
#  |-- Vintage_296: integer (nullable = true)
#  |-- Vintage_297: integer (nullable = true)
#  |-- Vintage_298: integer (nullable = true)
#  |-- Vintage_299: integer (nullable = true)
#  |-- Vintage_30: integer (nullable = true)
#  |-- Vintage_31: integer (nullable = true)
#  |-- Vintage_32: integer (nullable = true)
#  |-- Vintage_33: integer (nullable = true)
#  |-- Vintage_34: integer (nullable = true)
#  |-- Vintage_35: integer (nullable = true)
#  |-- Vintage_36: integer (nullable = true)
#  |-- Vintage_37: integer (nullable = true)
#  |-- Vintage_38: integer (nullable = true)
#  |-- Vintage_39: integer (nullable = true)
#  |-- Vintage_40: integer (nullable = true)
#  |-- Vintage_41: integer (nullable = true)
#  |-- Vintage_42: integer (nullable = true)
#  |-- Vintage_43: integer (nullable = true)
#  |-- Vintage_44: integer (nullable = true)
#  |-- Vintage_45: integer (nullable = true)
#  |-- Vintage_46: integer (nullable = true)
#  |-- Vintage_47: integer (nullable = true)
#  |-- Vintage_48: integer (nullable = true)
#  |-- Vintage_49: integer (nullable = true)
#  |-- Vintage_50: integer (nullable = true)
#  |-- Vintage_51: integer (nullable = true)
#  |-- Vintage_52: integer (nullable = true)
#  |-- Vintage_53: integer (nullable = true)
#  |-- Vintage_54: integer (nullable = true)
#  |-- Vintage_55: integer (nullable = true)
#  |-- Vintage_56: integer (nullable = true)
#  |-- Vintage_57: integer (nullable = true)
#  |-- Vintage_58: integer (nullable = true)
#  |-- Vintage_59: integer (nullable = true)
#  |-- Vintage_60: integer (nullable = true)
#  |-- Vintage_61: integer (nullable = true)
#  |-- Vintage_62: integer (nullable = true)
#  |-- Vintage_63: integer (nullable = true)
#  |-- Vintage_64: integer (nullable = true)
#  |-- Vintage_65: integer (nullable = true)
#  |-- Vintage_66: integer (nullable = true)
#  |-- Vintage_67: integer (nullable = true)
#  |-- Vintage_68: integer (nullable = true)
#  |-- Vintage_69: integer (nullable = true)
#  |-- Vintage_70: integer (nullable = true)
#  |-- Vintage_71: integer (nullable = true)
#  |-- Vintage_72: integer (nullable = true)
#  |-- Vintage_73: integer (nullable = true)
#  |-- Vintage_74: integer (nullable = true)
#  |-- Vintage_75: integer (nullable = true)
#  |-- Vintage_76: integer (nullable = true)
#  |-- Vintage_77: integer (nullable = true)
#  |-- Vintage_78: integer (nullable = true)
#  |-- Vintage_79: integer (nullable = true)
#  |-- Vintage_80: integer (nullable = true)
#  |-- Vintage_81: integer (nullable = true)
#  |-- Vintage_82: integer (nullable = true)
#  |-- Vintage_83: integer (nullable = true)
#  |-- Vintage_84: integer (nullable = true)
#  |-- Vintage_85: integer (nullable = true)
#  |-- Vintage_86: integer (nullable = true)
#  |-- Vintage_87: integer (nullable = true)
#  |-- Vintage_88: integer (nullable = true)
#  |-- Vintage_89: integer (nullable = true)
#  |-- Vintage_90: integer (nullable = true)
#  |-- Vintage_91: integer (nullable = true)
#  |-- Vintage_92: integer (nullable = true)
#  |-- Vintage_93: integer (nullable = true)
#  |-- Vintage_94: integer (nullable = true)
#  |-- Vintage_95: integer (nullable = true)
#  |-- Vintage_96: integer (nullable = true)
#  |-- Vintage_97: integer (nullable = true)
#  |-- Vintage_98: integer (nullable = true)
#  |-- Vintage_99: integer (nullable = true)
#  |-- Response: integer (nullable = true)

# %%
df = df.withColumnRenamed("Response", "label")

# %%
x_cols = [c for c in df.columns if c != "label"]

# %%
va = VectorAssembler(outputCol="features")
va.setInputCols(x_cols)

rf_model = RandomForestClassifier(
    
)
xgb_model = SparkXGBClassifier(
    num_workers=4
)

rf_pipeline = Pipeline(stages=[va, rf_model])
xgb_pipeline = Pipeline(stages=[va, xgb_model])

rf_paramgrid = ParamGridBuilder(
    
).build()
xgb_paramgrid = ParamGridBuilder(
    
).build()

bce = BinaryClassificationEvaluator()

rf_cv = StratifiedCrossValidator(
    estimator=rf_pipeline,
    estimatorParamMaps=rf_paramgrid,
    evaluator=bce,
    numFolds=2,
)

xgb_cv = StratifiedCrossValidator(
    estimator=xgb_pipeline,
    estimatorParamMaps=xgb_paramgrid,
    evaluator=bce,
    numFolds=2,
)

# %%
# %%time

OVERWRITE_RF_MODEL = False

if os.pa

rf_tuned = rf_cv.fit(df)
rf_tuned.write().overwrite().save("spark_models/rf_cv.model")

# %%
# %%time
xgb_tuned = xgb_cv.fit(df)
xgb_tuned.save("spark_models/xgb_cv.model")
# Out:
# 24/07/24 12:07:57 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# INFO:XGBoost-PySpark:Running xgboost-2.1.0 on 4 workers with
# 	booster params: {'device': 'cpu', 'objective': 'binary:logistic', 'nthread': 1}
# 	train_call_kwargs_params: {'verbose_eval': True, 'num_boost_round': 100}
# 	dmatrix_kwargs: {'nthread': 1, 'missing': nan}
# [Stage 14:==============================>                        (66 + 6) / 120]
